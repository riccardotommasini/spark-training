# %%
# !unzip local/data.zip -d data/
# Out:
# Archive:  local/data.zip
#    creating: data/data/
#    creating: data/data/events-500k.json/
#   inflating: data/data/products.csv
#   inflating: data/data/player.csv
#   inflating: data/data/.DS_Store
#   inflating: data/data/countries.csv
#   inflating: data/data/health_profile_data.snappy.parquet
#    creating: data/data/users.parquet/
#   inflating: data/data/weblog.log
#    creating: data/data/pageviews_by_second.parquet/
#    creating: data/data/events-2020-07-03.json/
#   inflating: data/data/airlines.csv
#   inflating: data/data/AliceInWonderLandPart1.txt
#    creating: data/data/2007-01-stream.parquet/
#    creating: data/data/events.parquet/
#   inflating: data/data/u.data
#   inflating: data/data/users.parquet.zip
#   inflating: data/data/kblist
#    creating: data/data/sales.parquet/
#   inflating: data/data/Chicago-Crimes-2018.csv
#   inflating: data/data/london_crime_by_lsoa.csv
#    creating: data/data/time-series-stream.json/
# ...
